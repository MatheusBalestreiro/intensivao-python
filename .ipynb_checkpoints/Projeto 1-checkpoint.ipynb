# %%
# !pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in c:\users\t-gamer\anaconda3\lib\site-packages (0.9.53)
# Requirement already satisfied: pymsgbox in c:\users\t-gamer\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\t-gamer\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\t-gamer\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: PyTweening>=1.0.1 in c:\users\t-gamer\anaconda3\lib\site-packages (from pyautogui) (1.0.4)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\t-gamer\anaconda3\lib\site-packages (from pyautogui) (0.1.28)
# Requirement already satisfied: pyrect in c:\users\t-gamer\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in c:\users\t-gamer\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)

# %%
import pyautogui
import time

pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema")
pyautogui.press("enter")

time.sleep(2)

pyautogui.press("tab")
pyautogui.write("Matheus")
pyautogui.press("tab")
pyautogui.write("Matheus")
pyautogui.hotkey("tab", "enter")
time.sleep(3)
pyautogui.hotkey("up", "enter")
time.sleep(2)
pyautogui.click(x=1838, y=129)

# %%
import time
import pyautogui

time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=165, y=190)

# %%
import pandas as pd

tabela = pd.read_csv(r"../Compras.csv", sep=";")
display(tabela)
total_gasto = tabela["ValorFinal"].sum()
quantidade = tabela["Quantidade"].sum()
preco_medio = total_gasto / quantidade

print(total_gasto)
print(quantitade)
print(preco_medio)
# Out:
#       CódigoCompra        Data               Fornecedor  \
# 0            65014  01/12/2023   Fabrica Hashtag Brasil
# 1            65014  01/12/2023   Fabrica Hashtag Brasil
# 2            65016  01/12/2023   Fabrica Doidona Brasil
# 3            65016  01/12/2023   Fabrica Doidona Brasil
# 4            65017  01/12/2023  Original Fábrica Brasil
# ...            ...         ...                      ...
# 4538         69996  26/12/2023        Revenda Argentina
# 4539         69996  26/12/2023        Revenda Argentina
# 4540         69996  26/12/2023        Revenda Argentina
# 4541         69997  26/12/2023   Fabrica Doidona Mexico
# 4542         69997  26/12/2023   Fabrica Doidona Mexico
#
#                             Produto  Quantidade ValorUnitário ValorFinal
# 0              Óleo Motor - Linha A           5           259       1295
# 1           Kit Embreagem - Linha A           1           380        380
# 2                 Bateria - Linha A           2           479        958
# 3          Filtro de Óleo - Linha A           1          18,9       18,9
# 4         Farol Principal - Linha A           3         159,9      479,7
# ...                             ...         ...           ...        ...
# 4538         Logo Hashtag - Linha A           2            10         20
# 4539  Terminal de Direção - Linha B           4         156,4      625,6
# 4540      Farol Principal - Linha B           1        183,89     183,89
# 4541                Pneus - Linha A           1        359,91     359,91
# 4542        Kit Embreagem - Linha C           2        502,55     1005,1
#
# [4543 rows x 7 columns]

# %% [markdown]
# #### import pyautogui
# pyautogui.hotkey("ctrl", "t")
# pyautogui.write("https://mail.google.com/mail/u/0/#inbox?compose=new")
# time.sleep(10)
# pyautogui.press("enter")
# pyautogui.click(x=165, y=190)
# pyautogui.write("Godzillawork1234@gmail.com")
# pyautogui.press("tab")
# pyautogui.write("Base de dados")
